# %% [markdown]
# # Replace DataSource Reference
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# A common practice when performing DataPrep is to build up a script or set of cleaning operations on a smaller example file locally. This is quicker and easier than dealing with large amounts of data initially.
#
# After building a Dataflow that performs the desired steps, it's time to run it against the larger dataset, which may be stored in the cloud, or even locally just in a different file. This is where we can use `Dataflow.replace_datasource` to get a Dataflow identical to the one built on the small data, but referencing the newly specified DataSource.

# %%
import azureml.dataprep as dprep

dflow = dprep.read_csv('../data/crime-spring.csv')
df = dflow.to_pandas_dataframe()
df
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
# 5  10535059    HZ278872   4/15/2016 4:30    004XX S KILBOURN AVE   810
# 6  10499802    HZ240778  4/15/2016 10:00   010XX N MILWAUKEE AVE  1152
# 7  10522293    HZ264802  4/15/2016 16:00     019XX W DIVISION ST  1110
# 8  10523111    HZ265911   4/15/2016 8:00     061XX N SHERIDAN RD  1153
# 9  10525877    HZ268138  4/15/2016 15:00    023XX W EASTWOOD AVE  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
# 5               THEFT                                OVER $500
# 6  DECEPTIVE PRACTICE                    ILLEGAL USE CASH CARD
# 7  DECEPTIVE PRACTICE                              BOGUS CHECK
# 8  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 9  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
# 5                 RESIDENCE  FALSE    FALSE              ...
# 6                 RESIDENCE  FALSE    FALSE              ...
# 7                RESTAURANT  FALSE    FALSE              ...
# 8                 RESIDENCE  FALSE    FALSE              ...
# 9                            FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
# 5   24             26        6                            2016
# 6   27             24       11                            2016
# 7    1             24       11      1163094      1908003  2016
# 8   48             77       11                            2016
# 9   47              4       11                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
# 5  5/25/2016 15:59
# 6  5/27/2016 15:45
# 7  5/16/2016 15:48  41.90320604  -87.67636193  (41.903206037, -87.676361925)
# 8  5/16/2016 15:50
# 9  5/18/2016 15:50
#
# [10 rows x 22 columns]

# %% [markdown]
# Here we have the first 10 rows of a dataset called 'Crime'. The original dataset is over 100MB (admittedly not that large of a dataset but this is just an example).
#
# We'll perform a few cleaning operations.

# %%
dflow_dropped = dflow.drop_columns(['Location', 'Updated On', 'X Coordinate', 'Y Coordinate', 'Description'])
sctb = dflow_dropped.builders.set_column_types()
sctb.learn(inference_arguments=dprep.InferenceArguments(day_first=False))
dflow_typed = sctb.to_dataflow()
dflow_typed.head(5)
# Out:
#            ID Case Number                Date                   Block    IUCR  \
# 0  10498554.0    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598.0    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196.0    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591.0    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446.0    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#          Primary Type      Location Description Arrest Domestic    Beat  \
# 0  DECEPTIVE PRACTICE                     OTHER  False    False   531.0
# 1               THEFT                 RESIDENCE  False    False   614.0
# 2  DECEPTIVE PRACTICE                 RESIDENCE  False    False  2211.0
# 3  DECEPTIVE PRACTICE                 RESIDENCE  False    False   531.0
# 4               THEFT  SCHOOL, PUBLIC, BUILDING  False    False  1712.0
#
#    District  Ward  Community Area  FBI Code    Year   Latitude  Longitude
# 0       5.0   9.0            50.0      11.0  2016.0  41.692834 -87.604319
# 1       6.0  21.0            71.0       6.0  2016.0  41.744107 -87.664494
# 2      22.0  19.0            74.0      11.0  2016.0        NaN        NaN
# 3       5.0   9.0            49.0      10.0  2016.0        NaN        NaN
# 4      17.0  40.0            13.0       6.0  2016.0        NaN        NaN

# %% [markdown]
# Now that we have a Dataflow with all our desired steps, we're ready to run against the 'full' dataset stored in Azure Blob.
# All we need to do is pass the BlobDataSource into `replace_datasource` and we'll get back an identical Dataflow with the new DataSource substituted in.

# %%
dflow_replaced = dflow_typed.replace_datasource(dprep.BlobDataSource('https://dpreptestfiles.blob.core.windows.net/testfiles/crime0.csv'))

# %% [markdown]
# 'replaced_dflow' will now pull data from the 168MB (729734 rows) version of Crime0.csv stored in Azure Blob!
#
# NOTE: Dataflows can also be created by referencing a different Dataflow. Instead of using `replace_datasource`, there is a corresponding `replace_reference` method.
#
# We should be careful now since pulling all that data down and putting it in a pandas dataframe isn't an ideal way to inspect the result of our Dataflow. So instead, to see that our steps are being applied to all the new data, we can add a `take_sample` step, which will select records at random (based on a given probability) to be returned.
#
# The probability below takes the ~730000 rows down to a more inspectable ~73, though the number will vary each time `to_pandas_dataframe()` is run, since they are being randomly selected based on the probability.

# %%
dflow_random_sample= dflow_replaced.take_sample(probability=0.0001)
sample = dflow_random_sample.to_pandas_dataframe()
sample
# Out:
#             ID Case Number  Date                     Block    IUCR  \
# 0   10112146.0    HY301420  None           016XX N VINE ST  1320.0
# 1    9682475.0    HX333024  None          036XX N CLARK ST  1320.0
# 2    9402822.0    HW546106  None  003XX N CENTRAL PARK AVE  1310.0
# 3    9155957.0    HW301718  None        013XX N HUDSON AVE   430.0
# 4    9067411.0    HW212414  None           014XX W 93RD ST  1320.0
# 5    9002699.0    HW149673  None        105XX S RHODES AVE   910.0
# 6    8833512.0    HV505865  None        057XX S ALBANY AVE  1320.0
# 7    8616586.0    HV290143  None         027XX N CANNON DR   820.0
# 8    8608605.0    HV282216  None           040XX W LAKE ST  1210.0
# 9    8606677.0    HV280125  None          0000X N STATE ST   860.0
# 10   8443149.0    HV121278  None      050XX W JACKSON BLVD  2820.0
# 11   8429698.0    HV107933  None       054XX W CHICAGO AVE   497.0
# 12   8333156.0    HT567513  None         027XX W CERMAK RD     NaN
# 13   7978656.0    HT211061  None      081XX S WOODLAWN AVE   910.0
# 14   7850926.0    HS663582  None         041XX W NELSON ST   610.0
# 15   7786929.0    HS586121  None           006XX E 50TH PL   610.0
# 16   7790408.0    HS599333  None       059XX N NAVARRE AVE   820.0
# 17   7644737.0    HS448704  None       123XX S EMERALD AVE   890.0
# 18   7580045.0    HS384385  None         003XX N UNION AVE   820.0
# 19   7377817.0    HS179649  None      102XX S MICHIGAN AVE   820.0
# 20   7264124.0    HR678419  None      058XX S MICHIGAN AVE   610.0
# 21   7221438.0    HR636639  None       050XX S LOOMIS BLVD   610.0
# 22   7070954.0    HR478276  None       106XX S OGLESBY AVE     NaN
# 23   7068624.0    HR476148  None        027XX S ELEANOR ST   820.0
# 24   7037402.0    HR422893  None     057XX S CLAREMONT AVE  1320.0
# 25   6933675.0    HR339233  None        023XX S WHIPPLE ST   460.0
# 26   6604621.0    HP677353  None         036XX S HOYNE AVE  2820.0
# 27   6574991.0    HP647146  None           015XX W 89TH ST  1320.0
# 28   6355826.0    HP443647  None         041XX N DAMEN AVE  2825.0
# 29   6199508.0    HP284539  None       0000X E RANDOLPH ST   560.0
# ..         ...         ...   ...                       ...     ...
# 45   3895219.0    HL272247  None      084XX S PHILLIPS AVE  1310.0
# 46   3893487.0    HL268773  None        093XX S LEAVITT ST  2825.0
# 47   3835187.0    HL205978  None        034XX W LYNDALE ST   560.0
# 48   3724952.0    HK829843  None      047XX W ARMITAGE AVE  1320.0
# 49   3710755.0    HK811979  None     013XX S SACRAMENTO DR   820.0
# 50   3744612.0    HK739644  None           013XX E 69TH ST  2092.0
# 51   3638215.0    HK733579  None           053XX W LAKE ST   560.0
# 52   3622238.0    HK714830  None      001XX N LAVERGNE AVE   560.0
# 53   3595426.0    HK660919  None        054XX S HALSTED ST  1506.0
# 54   3517236.0    HK586227  None        062XX S VERNON AVE     NaN
# 55   3365630.0    HK402123  None      007XX N RIDGEWAY AVE   486.0
# 56   3346941.0    HK389129  None      064XX N GLENWOOD AVE  4387.0
# 57   3268511.0    HK296671  None    059XX W IRVING PARK RD   486.0
# 58   3075540.0    HJ793241  None          014XX N LONG AVE   460.0
# 59   3060753.0    HJ777817  None      049XX S MICHIGAN AVE   810.0
# 60   3143948.0    HK136843  None        043XX N SAWYER AVE  1563.0
# 61   2933086.0    HJ613051  None       009XX N KEDVALE AVE   910.0
# 62   2756088.0    HJ395890  None          058XX N BROADWAY  1320.0
# 63   2719288.0    HJ314195  None      043XX W VAN BUREN ST  2095.0
# 64   2697488.0    HJ313567  None        049XX S WABASH AVE  2840.0
# 65   2962974.0    HJ654724  None     001XX W DIVERSEY PKWY  1130.0
# 66   2921530.0    HJ600723  None          083XX S GREEN ST  1310.0
# 67   2271397.0    HH550243  None         095XX S THROOP ST   890.0
# 68   2263618.0    HH536245  None      042XX W VAN BUREN ST   326.0
# 69   1764531.0     G578089  None       016XX N OAK PARK AV   810.0
# 70   1651969.0     G437955  None     018XX S CALIFORNIA AV  5002.0
# 71   1615094.0     G389081  None       005XX S DEARBORN ST   470.0
# 72   1597685.0     G357045  None         029XX W MONROE ST  2095.0
# 73   1575097.0     G334027  None        058XX S PRAIRIE AV  1811.0
# 74   1353799.0     G056142  None       006XX N MICHIGAN AV   820.0
#
#               Primary Type            Location Description Arrest Domestic  \
# 0          CRIMINAL DAMAGE                          STREET  False    False
# 1          CRIMINAL DAMAGE  PARKING LOT/GARAGE(NON.RESID.)  False    False
# 2          CRIMINAL DAMAGE                       APARTMENT   True    False
# 3                  BATTERY                       RESIDENCE  False    False
# 4          CRIMINAL DAMAGE                          STREET  False    False
# 5      MOTOR VEHICLE THEFT                          STREET  False    False
# 6          CRIMINAL DAMAGE                           ALLEY  False    False
# 7                    THEFT                          STREET  False    False
# 8       DECEPTIVE PRACTICE                    CTA PLATFORM   True    False
# 9                    THEFT                DEPARTMENT STORE   True    False
# 10           OTHER OFFENSE                       RESIDENCE  False    False
# 11                 BATTERY                          STREET  False     True
# 12           OTHER OFFENSE                          STREET  False    False
# 13     MOTOR VEHICLE THEFT                          STREET  False    False
# 14                BURGLARY                       RESIDENCE  False    False
# 15                BURGLARY                       APARTMENT  False    False
# 16                   THEFT                          STREET  False    False
# 17                   THEFT                       RESIDENCE  False    False
# 18                   THEFT                          STREET  False    False
# 19                   THEFT                RESIDENCE-GARAGE  False    False
# 20                BURGLARY                       APARTMENT  False    False
# 21                BURGLARY                       RESIDENCE  False    False
# 22       WEAPONS VIOLATION                          STREET   True    False
# 23                   THEFT                          STREET  False    False
# 24         CRIMINAL DAMAGE                          STREET  False    False
# 25                 BATTERY                        SIDEWALK  False    False
# 26           OTHER OFFENSE                       RESIDENCE  False     True
# 27         CRIMINAL DAMAGE                          STREET  False    False
# 28           OTHER OFFENSE                       RESIDENCE  False    False
# 29                 ASSAULT                           OTHER  False    False
# ..                     ...                             ...    ...      ...
# 45         CRIMINAL DAMAGE                       RESIDENCE  False    False
# 46           OTHER OFFENSE                       RESIDENCE  False     True
# 47                 ASSAULT                       APARTMENT  False     True
# 48         CRIMINAL DAMAGE  PARKING LOT/GARAGE(NON.RESID.)  False    False
# 49                   THEFT        SCHOOL, PUBLIC, BUILDING  False    False
# 50               NARCOTICS                        SIDEWALK   True    False
# 51                 ASSAULT                        SIDEWALK  False    False
# 52                 ASSAULT                          STREET  False    False
# 53            PROSTITUTION                          STREET   True    False
# 54       WEAPONS VIOLATION                       APARTMENT   True    False
# 55                 BATTERY                       RESIDENCE  False     True
# 56           OTHER OFFENSE                       APARTMENT   True    False
# 57                 BATTERY             TAVERN/LIQUOR STORE  False     True
# 58                 BATTERY                       RESIDENCE  False    False
# 59                   THEFT                 VACANT LOT/LAND  False    False
# 60             SEX OFFENSE                       RESIDENCE   True    False
# 61     MOTOR VEHICLE THEFT                          STREET  False    False
# 62         CRIMINAL DAMAGE                          STREET  False    False
# 63               NARCOTICS                          STREET   True    False
# 64  PUBLIC PEACE VIOLATION        SCHOOL, PUBLIC, BUILDING  False    False
# 65      DECEPTIVE PRACTICE                           OTHER   True    False
# 66         CRIMINAL DAMAGE                       RESIDENCE  False    False
# 67                   THEFT        SCHOOL, PUBLIC, BUILDING  False    False
# 68                 ROBBERY                          STREET  False    False
# 69                   THEFT                          STREET  False    False
# 70           OTHER OFFENSE                          STREET   True    False
# 71  PUBLIC PEACE VIOLATION                          STREET   True    False
# 72               NARCOTICS                          STREET   True    False
# 73               NARCOTICS                        SIDEWALK   True    False
# 74                   THEFT                     HOTEL/MOTEL  False    False
#
#       Beat  District  Ward  Community Area  FBI Code    Year   Latitude  \
# 0   1813.0      18.0  43.0             7.0      14.0  2015.0  41.911678
# 1   1923.0      19.0  44.0             6.0      14.0  2014.0  41.947258
# 2   1123.0      11.0  28.0            27.0      14.0  2013.0  41.886515
# 3   1821.0      18.0  27.0             8.0       NaN  2013.0  41.907301
# 4   2222.0      22.0  21.0            73.0      14.0  2013.0  41.724791
# 5    512.0       5.0   9.0            49.0       7.0  2013.0  41.702997
# 6    824.0       8.0  14.0            63.0      14.0  2012.0  41.789774
# 7   1935.0      19.0  43.0             7.0       6.0  2012.0  41.931115
# 8   1114.0      11.0  28.0            26.0      11.0  2012.0  41.885361
# 9    112.0       1.0  42.0            32.0       6.0  2012.0  41.882538
# 10  1533.0      15.0  28.0            25.0      26.0  2012.0  41.876578
# 11  1524.0      15.0  37.0            25.0       NaN  2012.0  41.894758
# 12  1023.0      10.0  28.0            30.0      26.0  2011.0  41.852029
# 13   411.0       4.0   8.0            45.0       7.0  2011.0  41.747646
# 14  2523.0      25.0  31.0            21.0       5.0  2010.0  41.936175
# 15   223.0       2.0   4.0            38.0       5.0  2010.0  41.803018
# 16  1611.0      16.0  41.0            10.0       6.0  2010.0  41.989770
# 17   523.0       5.0  34.0            53.0       6.0  2010.0  41.669007
# 18  1212.0      12.0  27.0            28.0       6.0  2010.0  41.887529
# 19   511.0       5.0   9.0            49.0       6.0  2010.0  41.708400
# 20   233.0       2.0  20.0            40.0       5.0  2009.0  41.789060
# 21   933.0       9.0  16.0            61.0       5.0  2009.0  41.802017
# 22   434.0       4.0  10.0            51.0      15.0  2009.0  41.702555
# 23   923.0       9.0  11.0            60.0       6.0  2009.0  41.844397
# 24   824.0       8.0  16.0            63.0      14.0  2009.0  41.789414
# 25  1033.0      10.0  12.0            30.0       NaN  2009.0  41.848999
# 26   913.0       9.0  11.0            59.0      26.0  2008.0  41.827403
# 27  2221.0      22.0  21.0            73.0      14.0  2008.0  41.731988
# 28  1912.0      19.0  47.0             5.0      26.0  2008.0  41.957260
# 29   122.0       1.0  42.0            32.0       NaN  2008.0  41.884385
# ..     ...       ...   ...             ...       ...     ...        ...
# 45   423.0       4.0   7.0            46.0      14.0  2005.0  41.741024
# 46  2221.0      22.0  19.0            72.0      26.0  2005.0  41.724374
# 47  1413.0      14.0  26.0            22.0       NaN  2005.0  41.922021
# 48  2522.0      25.0  31.0            19.0      14.0  2004.0  41.917060
# 49  1022.0      10.0  24.0            29.0       6.0  2004.0  41.864143
# 50   321.0       3.0   5.0            69.0      26.0  2004.0  41.769785
# 51  1523.0      15.0  28.0            25.0       NaN  2004.0  41.887210
# 52  1532.0      15.0  28.0            25.0       NaN  2004.0  41.882262
# 53   934.0       9.0   3.0            61.0      16.0  2004.0  41.795653
# 54   313.0       3.0  20.0            42.0      15.0  2004.0  41.781962
# 55  1112.0      11.0  27.0            23.0       NaN  2004.0  41.894571
# 56  2432.0      24.0  40.0             1.0      26.0  2004.0  41.998377
# 57  1633.0      16.0  38.0            15.0       NaN  2004.0  41.952973
# 58  2532.0      25.0  37.0            25.0       NaN  2003.0  41.906964
# 59   231.0       2.0   3.0            38.0       6.0  2003.0  41.805634
# 60  1724.0      17.0  33.0            16.0      17.0  2003.0  41.960603
# 61  1111.0      11.0  37.0            23.0       7.0  2003.0  41.897331
# 62  2022.0       NaN  48.0            77.0      14.0  2003.0  41.988094
# 63  1131.0       NaN  24.0            26.0      18.0  2003.0  41.875050
# 64   231.0       NaN   3.0            38.0      24.0  2003.0  41.804549
# 65  2333.0      19.0  44.0             6.0      11.0  2003.0  41.933214
# 66   613.0       6.0  21.0            71.0      14.0  2003.0  41.741627
# 67  2213.0       NaN  21.0            73.0       6.0  2002.0  41.721255
# 68  1132.0       NaN  24.0            26.0       3.0  2002.0  41.875067
# 69  2513.0       NaN   NaN             NaN       6.0  2001.0  41.910694
# 70  1022.0       NaN   NaN             NaN      26.0  2001.0  41.857292
# 71   132.0       NaN   NaN             NaN      24.0  2001.0  41.874965
# 72  1124.0       NaN   NaN             NaN      18.0  2001.0  41.880471
# 73   233.0       NaN   NaN             NaN      18.0  2001.0  41.789203
# 74  1834.0       NaN   NaN             NaN       6.0  2001.0  41.894826
#
#     Longitude
# 0  -87.644525
# 1  -87.656732
# 2  -87.715913
# 3  -87.639539
# 4  -87.659610
# 5  -87.610133
# 6  -87.701158
# 7  -87.637315
# 8  -87.725935
# 9  -87.627997
# 10 -87.752599
# 11 -87.763493
# 12 -87.693932
# 13 -87.595257
# 14 -87.732454
# 15 -87.609083
# 16 -87.792214
# 17 -87.640563
# 18 -87.645589
# 19 -87.620170
# 20 -87.622177
# 21 -87.659788
# 22 -87.565298
# 23 -87.660357
# 24 -87.682365
# 25 -87.701354
# 26 -87.677497
# 27 -87.661202
# 28 -87.678998
# 29 -87.625862
# ..        ...
# 45 -87.564715
# 46 -87.677172
# 47 -87.712477
# 48 -87.744413
# 49 -87.702005
# 50 -87.593746
# 51 -87.758841
# 52 -87.750094
# 53 -87.645047
# 54 -87.614604
# 55 -87.719802
# 56 -87.665664
# 57 -87.774346
# 58 -87.760710
# 59 -87.622892
# 60 -87.709602
# 61 -87.729987
# 62 -87.660059
# 63 -87.734011
# 64 -87.624485
# 65 -87.633132
# 66 -87.645202
# 67 -87.655530
# 68 -87.732561
# 69 -87.794697
# 70 -87.695781
# 71 -87.629072
# 72 -87.700412
# 73 -87.619231
# 74 -87.624399
#
# [75 rows x 17 columns]
