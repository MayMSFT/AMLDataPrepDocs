# %% [markdown]
# # Replace DataSource Reference
# Copyright (c) Microsoft Corporation. All rights reserved.<br>
# Licensed under the MIT License.

# %% [markdown]
# A common practice when performing DataPrep is to build up a script or set of cleaning operations on a smaller example file locally. This is quicker and easier than dealing with large amounts of data initially.
#
# After building a Dataflow that performs the desired steps, it's time to run it against the larger dataset, which may be stored in the cloud, or even locally just in a different file. This is where we can use `Dataflow.replace_datasource` to get a Dataflow identical to the one built on the small data, but referencing the newly specified DataSource.

# %%
import azureml.dataprep as dprep

dflow = dprep.read_csv('../data/crime-spring.csv')
df = dflow.to_pandas_dataframe()
df
# Out:
#          ID Case Number             Date                   Block  IUCR  \
# 0  10498554    HZ239907  4/15/2016 23:56        007XX E 111TH ST  1153
# 1  10516598    HZ258664  4/15/2016 17:00  082XX S MARSHFIELD AVE   890
# 2  10519196    HZ261252  4/15/2016 10:00  104XX S SACRAMENTO AVE  1154
# 3  10519591    HZ261534   4/15/2016 9:00     113XX S PRAIRIE AVE  1120
# 4  10534446    HZ277630  4/15/2016 10:00      055XX N KEDZIE AVE   890
# 5  10535059    HZ278872   4/15/2016 4:30    004XX S KILBOURN AVE   810
# 6  10499802    HZ240778  4/15/2016 10:00   010XX N MILWAUKEE AVE  1152
# 7  10522293    HZ264802  4/15/2016 16:00     019XX W DIVISION ST  1110
# 8  10523111    HZ265911   4/15/2016 8:00     061XX N SHERIDAN RD  1153
# 9  10525877    HZ268138  4/15/2016 15:00    023XX W EASTWOOD AVE  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1               THEFT                            FROM BUILDING
# 2  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 3  DECEPTIVE PRACTICE                                  FORGERY
# 4               THEFT                            FROM BUILDING
# 5               THEFT                                OVER $500
# 6  DECEPTIVE PRACTICE                    ILLEGAL USE CASH CARD
# 7  DECEPTIVE PRACTICE                              BOGUS CHECK
# 8  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 9  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#        Location Description Arrest Domestic              ...                \
# 0                     OTHER  FALSE    FALSE              ...
# 1                 RESIDENCE  FALSE    FALSE              ...
# 2                 RESIDENCE  FALSE    FALSE              ...
# 3                 RESIDENCE  FALSE    FALSE              ...
# 4  SCHOOL, PUBLIC, BUILDING  FALSE    FALSE              ...
# 5                 RESIDENCE  FALSE    FALSE              ...
# 6                 RESIDENCE  FALSE    FALSE              ...
# 7                RESTAURANT  FALSE    FALSE              ...
# 8                 RESIDENCE  FALSE    FALSE              ...
# 9                            FALSE    FALSE              ...
#
#   Ward Community Area FBI Code X Coordinate Y Coordinate  Year  \
# 0    9             50       11      1183356      1831503  2016
# 1   21             71        6      1166776      1850053  2016
# 2   19             74       11                            2016
# 3    9             49       10                            2016
# 4   40             13        6                            2016
# 5   24             26        6                            2016
# 6   27             24       11                            2016
# 7    1             24       11      1163094      1908003  2016
# 8   48             77       11                            2016
# 9   47              4       11                            2016
#
#         Updated On     Latitude     Longitude                       Location
# 0  5/11/2016 15:48  41.69283384  -87.60431945   (41.692833841, -87.60431945)
# 1  5/12/2016 15:48  41.74410697  -87.66449429  (41.744106973, -87.664494285)
# 2  5/12/2016 15:50
# 3  5/13/2016 15:51
# 4  5/25/2016 15:59
# 5  5/25/2016 15:59
# 6  5/27/2016 15:45
# 7  5/16/2016 15:48  41.90320604  -87.67636193  (41.903206037, -87.676361925)
# 8  5/16/2016 15:50
# 9  5/18/2016 15:50
#
# [10 rows x 22 columns]

# %% [markdown]
# Here we have the first 10 rows of a dataset called 'Crime'. The original dataset is over 100MB (admittedly not that large of a dataset but this is just an example).
#
# We'll perform a few cleaning operations.

# %%
dflow_dropped = dflow.drop_columns(['Location', 'Updated On', 'X Coordinate', 'Y Coordinate', 'Description'])
sctb = dflow_dropped.builders.set_column_types()
sctb.learn(inference_arguments=dprep.InferenceArguments(day_first=False))
dflow_typed = sctb.to_dataflow()
dflow_typed.head(5)
# Out:
#            ID Case Number                Date                   Block    IUCR  \
# 0  10498554.0    HZ239907 2016-04-15 23:56:00        007XX E 111TH ST  1153.0
# 1  10516598.0    HZ258664 2016-04-15 17:00:00  082XX S MARSHFIELD AVE   890.0
# 2  10519196.0    HZ261252 2016-04-15 10:00:00  104XX S SACRAMENTO AVE  1154.0
# 3  10519591.0    HZ261534 2016-04-15 09:00:00     113XX S PRAIRIE AVE  1120.0
# 4  10534446.0    HZ277630 2016-04-15 10:00:00      055XX N KEDZIE AVE   890.0
#
#          Primary Type      Location Description Arrest Domestic    Beat  \
# 0  DECEPTIVE PRACTICE                     OTHER  False    False   531.0
# 1               THEFT                 RESIDENCE  False    False   614.0
# 2  DECEPTIVE PRACTICE                 RESIDENCE  False    False  2211.0
# 3  DECEPTIVE PRACTICE                 RESIDENCE  False    False   531.0
# 4               THEFT  SCHOOL, PUBLIC, BUILDING  False    False  1712.0
#
#    District  Ward  Community Area  FBI Code    Year   Latitude  Longitude
# 0       5.0   9.0            50.0      11.0  2016.0  41.692834 -87.604319
# 1       6.0  21.0            71.0       6.0  2016.0  41.744107 -87.664494
# 2      22.0  19.0            74.0      11.0  2016.0        NaN        NaN
# 3       5.0   9.0            49.0      10.0  2016.0        NaN        NaN
# 4      17.0  40.0            13.0       6.0  2016.0        NaN        NaN

# %% [markdown]
# Now that we have a Dataflow with all our desired steps, we're ready to run against the 'full' dataset stored in Azure Blob.
# All we need to do is pass the BlobDataSource into `replace_datasource` and we'll get back an identical Dataflow with the new DataSource substituted in.

# %%
dflow_replaced = dflow_typed.replace_datasource(dprep.BlobDataSource('https://dpreptestfiles.blob.core.windows.net/testfiles/crime0.csv'))

# %% [markdown]
# 'replaced_dflow' will now pull data from the 168MB (729734 rows) version of Crime0.csv stored in Azure Blob!
#
# NOTE: Dataflows can also be created by referencing a different Dataflow. Instead of using `replace_datasource`, there is a corresponding `replace_reference` method.
#
# We should be careful now since pulling all that data down and putting it in a pandas dataframe isn't an ideal way to inspect the result of our Dataflow. So instead, to see that our steps are being applied to all the new data, we can add a `take_sample` step, which will select records at random (based on a given probability) to be returned.
#
# The probability below takes the ~730000 rows down to a more inspectable ~73, though the number will vary each time `to_pandas_dataframe()` is run, since they are being randomly selected based on the probability.

# %%
dflow_random_sample= dflow_replaced.take_sample(probability=0.0001)
sample = dflow_random_sample.to_pandas_dataframe()
sample
# Out:
#             ID Case Number  Date                         Block    IUCR  \
# 0   10020232.0    HY209151  None            054XX W HADDON AVE   486.0
# 1    9996712.0    HY186990  None            052XX W MADISON ST   860.0
# 2    9993753.0    HY183842  None               016XX E 67TH ST   460.0
# 3    9903956.0    HX554134  None               016XX W 81ST ST  1330.0
# 4    9420981.0    HW565023  None       012XX W NORTH SHORE AVE  1220.0
# 5    9267612.0    HW412612  None              007XX E 130TH PL  1340.0
# 6    9231072.0    HW372701  None          070XX S EAST END AVE   486.0
# 7    9146770.0    HW292388  None             107XX S YATES AVE   486.0
# 8    9074521.0    HW219115  None             046XX W NORTH AVE  1152.0
# 9    9003672.0    HW150977  None              025XX W HURON ST  1320.0
# 10   8851881.0    HV525029  None           072XX S ROCKWELL ST  2820.0
# 11   8584146.0    HV258586  None             001XX N LOTUS AVE   486.0
# 12   8430496.0    HV108863  None           052XX N LARAMIE AVE  1310.0
# 13   8389999.0    HT622694  None            020XX N BURLING ST   810.0
# 14   8393656.0    HT620731  None             014XX W NORTH AVE  1152.0
# 15   8264831.0    HT498266  None            048XX S WABASH AVE   870.0
# 16   8101273.0    HT335886  None            054XX N SAWYER AVE   890.0
# 17   7999387.0    HT230697  None             090XX S CLYDE AVE   820.0
# 18   7989461.0    HT221314  None         114XX S EGGLESTON AVE  1811.0
# 19   7835987.0    HS647807  None            073XX S RACINE AVE  1811.0
# 20   7749417.0    HS547911  None             075XX S ELLIS AVE   330.0
# 21   7360270.0    HS161525  None            045XX N MOBILE AVE   486.0
# 22   7295345.0    HR712524  None            131XX S VERNON AVE   610.0
# 23   7284434.0    HR605281  None           046XX N KENMORE AVE   460.0
# 24   7102874.0    HR512188  None            063XX W CUYLER AVE  1320.0
# 25   7024888.0    HR392635  None          007XX N TRUMBULL AVE  2024.0
# 26   6796884.0    HR209045  None  002XX W MERCHANDISE MART PLZ     NaN
# 27   6746974.0    HR164560  None             008XX W BUENA AVE  1320.0
# 28   6055830.0    HP155148  None             004XX W NORTH AVE  1305.0
# 29   5788056.0    HN596062  None     004XX N CENTRAL PARK BLVD   330.0
# ..         ...         ...   ...                           ...     ...
# 36   4538816.0    HM127001  None             114XX S PERRY AVE   820.0
# 37   4333919.0    HL637025  None              096XX S AVENUE N  1320.0
# 38   3844991.0    HL219097  None              001XX N STATE ST   860.0
# 39   3794408.0    HL155865  None            059XX S RACINE AVE   810.0
# 40   3673790.0    HK775233  None             049XX S KOLIN AVE   820.0
# 41   3509551.0    HK582122  None           121XX S EMERALD AVE   337.0
# 42   3501512.0    HK557876  None           039XX W DIVISION ST   460.0
# 43   3387052.0    HK439824  None               077XX S WOOD ST  1310.0
# 44   3351267.0    HK379895  None          004XX N LOCKWOOD AVE     NaN
# 45   3169470.0    HK168245  None           026XX W RASCHER AVE   486.0
# 46   3059227.0    HJ775082  None          018XX N LECLAIRE AVE   910.0
# 47   3027345.0    HJ737085  None           043XX S WOLCOTT AVE   460.0
# 48   2924473.0    HJ592081  None      006XX N CENTRAL PARK AVE   610.0
# 49   2856988.0    HJ521489  None        010XX N MARSHFIELD AVE   460.0
# 50   2757284.0    HJ398057  None         008XX W FULLERTON AVE   460.0
# 51   2621190.0    HJ226354  None            052XX S PULASKI RD  1320.0
# 52   2521621.0    HH838178  None            023XX S SAWYER AVE  1811.0
# 53   2488315.0    HH825261  None               037XX W 59TH PL  1310.0
# 54   2413269.0    HH704591  None           036XX W CHICAGO AVE   810.0
# 55   2210477.0    HH444074  None               010XX N RUSH ST   560.0
# 56   2146371.0    HH389238  None          022XX S MICHIGAN AVE   820.0
# 57   1970983.0    HH164463  None              073XX S YATES AV   620.0
# 58   1935899.0    HH120382  None                 041XX W 24 PL   630.0
# 59   1933364.0    HH117923  None                 034XX W 65 PL   820.0
# 60   1904140.0     G759395  None               070XX S LOWE AV   610.0
# 61   1910187.0     G667641  None             109XX S LOOMIS ST  2017.0
# 62   1551355.0     G305391  None            063XX S LANGLEY AV   313.0
# 63   1504124.0     G247576  None            050XX N LINCOLN AV  1330.0
# 64   1398888.0     G102474  None            030XX N WESTERN AV  2027.0
# 65   1373058.0     G080045  None             031XX N CICERO AV   610.0
#
#            Primary Type            Location Description Arrest Domestic  \
# 0               BATTERY                       APARTMENT  False     True
# 1                 THEFT               CONVENIENCE STORE   True    False
# 2               BATTERY                       APARTMENT  False    False
# 3     CRIMINAL TRESPASS                     GAS STATION   True    False
# 4    DECEPTIVE PRACTICE                        SIDEWALK  False    False
# 5       CRIMINAL DAMAGE  CHA HALLWAY/STAIRWELL/ELEVATOR   True     True
# 6               BATTERY   RESIDENTIAL YARD (FRONT/BACK)  False     True
# 7               BATTERY                        SIDEWALK  False     True
# 8    DECEPTIVE PRACTICE                DEPARTMENT STORE  False    False
# 9       CRIMINAL DAMAGE          VEHICLE NON-COMMERCIAL  False    False
# 10        OTHER OFFENSE                       RESIDENCE  False    False
# 11              BATTERY                           ALLEY  False     True
# 12      CRIMINAL DAMAGE         RESIDENCE PORCH/HALLWAY  False    False
# 13                THEFT                          STREET  False    False
# 14   DECEPTIVE PRACTICE              SMALL RETAIL STORE  False    False
# 15                THEFT                       RESIDENCE  False    False
# 16                THEFT                RESIDENCE-GARAGE  False    False
# 17                THEFT                          STREET  False    False
# 18            NARCOTICS                          STREET   True    False
# 19            NARCOTICS                       APARTMENT   True    False
# 20              ROBBERY                           ALLEY  False    False
# 21              BATTERY                       RESIDENCE  False     True
# 22             BURGLARY                       RESIDENCE  False    False
# 23              BATTERY                          STREET  False    False
# 24      CRIMINAL DAMAGE                          STREET  False    False
# 25            NARCOTICS                        SIDEWALK   True    False
# 26              ROBBERY                       CTA TRAIN  False    False
# 27      CRIMINAL DAMAGE                          STREET  False    False
# 28      CRIMINAL DAMAGE    COMMERCIAL / BUSINESS OFFICE   True    False
# 29              ROBBERY                          STREET  False    False
# ..                  ...                             ...    ...      ...
# 36                THEFT                           OTHER  False    False
# 37      CRIMINAL DAMAGE                          STREET   True    False
# 38                THEFT                DEPARTMENT STORE   True    False
# 39                THEFT               CURRENCY EXCHANGE  False    False
# 40                THEFT                          STREET  False    False
# 41              ROBBERY                        SIDEWALK  False    False
# 42              BATTERY                        SIDEWALK  False     True
# 43      CRIMINAL DAMAGE                       RESIDENCE  False    False
# 44    WEAPONS VIOLATION                          STREET   True    False
# 45              BATTERY                          STREET  False    False
# 46  MOTOR VEHICLE THEFT  PARKING LOT/GARAGE(NON.RESID.)  False    False
# 47              BATTERY                       APARTMENT  False    False
# 48             BURGLARY                       RESIDENCE  False    False
# 49              BATTERY                          STREET  False    False
# 50              BATTERY                          STREET  False    False
# 51      CRIMINAL DAMAGE  PARKING LOT/GARAGE(NON.RESID.)  False    False
# 52            NARCOTICS                        SIDEWALK   True    False
# 53      CRIMINAL DAMAGE                RESIDENCE-GARAGE  False    False
# 54                THEFT    COMMERCIAL / BUSINESS OFFICE  False     True
# 55              ASSAULT                        SIDEWALK   True    False
# 56                THEFT                          STREET  False    False
# 57             BURGLARY                       APARTMENT  False    False
# 58             BURGLARY                       APARTMENT  False    False
# 59                THEFT        SCHOOL, PUBLIC, BUILDING  False    False
# 60             BURGLARY                       RESIDENCE  False    False
# 61            NARCOTICS                          STREET   True    False
# 62              ROBBERY                        SIDEWALK  False    False
# 63    CRIMINAL TRESPASS              GROCERY FOOD STORE   True    False
# 64            NARCOTICS                          STREET   True    False
# 65             BURGLARY    COMMERCIAL / BUSINESS OFFICE  False    False
#
#       Beat  District  Ward  Community Area  FBI Code    Year   Latitude  \
# 0   1524.0      15.0  37.0            25.0       NaN  2015.0  41.901163
# 1   1522.0      15.0  29.0            25.0       6.0  2015.0  41.880260
# 2    332.0       3.0   5.0            43.0       NaN  2015.0  41.773240
# 3    611.0       6.0  21.0            71.0      26.0  2014.0  41.746817
# 4   2432.0      24.0  49.0             1.0      11.0  2013.0  42.003629
# 5    533.0       5.0   9.0            54.0      14.0  2013.0  41.658600
# 6    332.0       3.0   5.0            43.0       NaN  2013.0  41.767515
# 7    434.0       4.0  10.0            51.0       NaN  2013.0  41.700695
# 8   2533.0      25.0  37.0            25.0      11.0  2013.0  41.909766
# 9   1221.0      12.0  26.0            24.0      14.0  2013.0  41.894010
# 10   832.0       8.0  18.0            66.0      26.0  2012.0  41.762705
# 11  1523.0      15.0  28.0            25.0       NaN  2012.0  41.882831
# 12  1623.0      16.0  45.0            11.0      14.0  2012.0  41.976301
# 13  1812.0      18.0  43.0             7.0       6.0  2011.0  41.919441
# 14  1433.0      14.0  32.0            24.0      11.0  2011.0  41.910804
# 15   231.0       2.0   3.0            38.0       6.0  2011.0  41.807209
# 16  1712.0      17.0  40.0            13.0       6.0  2011.0  41.980485
# 17   413.0       4.0   7.0            48.0       6.0  2011.0  41.730983
# 18  2233.0      22.0  34.0            49.0      18.0  2011.0  41.686476
# 19   733.0       7.0  17.0            68.0      18.0  2010.0  41.761328
# 20   624.0       6.0   8.0            69.0       3.0  2010.0  41.757445
# 21  1622.0      16.0  38.0            15.0       NaN  2010.0  41.962306
# 22   533.0       5.0   9.0            54.0       5.0  2009.0  41.657147
# 23  2312.0      19.0  46.0             3.0       NaN  2009.0  41.967055
# 24  1624.0      16.0  38.0            15.0      14.0  2009.0  41.953737
# 25  1121.0      11.0  27.0            23.0      18.0  2009.0  41.893845
# 26  1831.0      18.0  42.0             8.0       3.0  2009.0  41.888072
# 27  2322.0      19.0  46.0             3.0      14.0  2009.0  41.958344
# 28  1821.0      18.0  43.0             8.0      14.0  2008.0  41.911001
# 29  1122.0      11.0  27.0            23.0       3.0  2007.0  41.888671
# ..     ...       ...   ...             ...       ...     ...        ...
# 36   522.0       5.0  34.0            49.0       6.0  2006.0  41.685965
# 37   432.0       4.0  10.0            52.0      14.0  2005.0  41.720218
# 38   122.0       1.0  42.0            32.0       6.0  2005.0  41.883560
# 39   712.0       7.0  16.0            68.0       6.0  2005.0  41.786884
# 40   815.0       8.0  23.0            57.0       6.0  2004.0  41.802402
# 41   523.0       5.0  34.0            53.0       3.0  2004.0  41.674173
# 42  1112.0      11.0  27.0            23.0       NaN  2004.0  41.902570
# 43   611.0       6.0  17.0            71.0      14.0  2004.0  41.752794
# 44  1523.0      15.0  28.0            25.0      15.0  2004.0  41.887846
# 45  2011.0      20.0  40.0             4.0       NaN  2004.0  41.980290
# 46  2533.0      25.0  37.0            25.0       7.0  2003.0  41.913696
# 47   914.0       9.0  12.0            61.0       NaN  2003.0  41.814689
# 48  1122.0      11.0  27.0            23.0       5.0  2003.0  41.892701
# 49  1322.0      12.0   1.0            24.0       NaN  2003.0  41.900749
# 50  1933.0       NaN  43.0             7.0       NaN  2003.0  41.925542
# 51   815.0       NaN  23.0            62.0      14.0  2003.0  41.797990
# 52  1024.0       NaN  22.0            30.0      18.0  2002.0  41.849911
# 53   822.0       NaN  13.0            65.0      14.0  2002.0  41.785224
# 54  1112.0       NaN  27.0            23.0       6.0  2002.0  41.895333
# 55  1824.0       NaN  42.0             8.0       NaN  2002.0  41.902001
# 56   134.0       NaN   2.0            33.0       6.0  2002.0  41.851366
# 57   334.0       NaN   NaN             NaN       5.0  2002.0  41.761345
# 58  1013.0       NaN   NaN             NaN       5.0  2002.0  41.847065
# 59   831.0       NaN   NaN             NaN       6.0  2001.0  41.774446
# 60   732.0       NaN   NaN             NaN       5.0  2001.0  41.766307
# 61  2234.0       NaN   NaN             NaN      18.0  2001.0  41.694859
# 62   312.0       NaN   NaN             NaN       3.0  2001.0  41.778867
# 63  2031.0       NaN   NaN             NaN      26.0  2001.0  41.973097
# 64  1411.0       NaN   NaN             NaN      18.0  2001.0  41.936017
# 65  2521.0       NaN   NaN             NaN       5.0  2001.0  41.937462
#
#     Longitude
# 0  -87.761692
# 1  -87.755187
# 2  -87.584805
# 3  -87.663843
# 4  -87.662434
# 5  -87.604131
# 6  -87.582672
# 7  -87.564137
# 8  -87.743312
# 9  -87.690927
# 10 -87.687936
# 11 -87.761774
# 12 -87.757655
# 13 -87.647201
# 14 -87.663451
# 15 -87.624254
# 16 -87.710166
# 17 -87.572993
# 18 -87.633592
# 19 -87.653873
# 20 -87.600341
# 21 -87.784578
# 22 -87.611433
# 23 -87.656354
# 24 -87.785467
# 25 -87.712757
# 26 -87.634977
# 27 -87.652527
# 28 -87.638783
# 29 -87.716722
# ..        ...
# 36 -87.625484
# 37 -87.538769
# 38 -87.627736
# 39 -87.654538
# 40 -87.732147
# 41 -87.640764
# 42 -87.725386
# 43 -87.668501
# 44 -87.757642
# 45 -87.696052
# 46 -87.752950
# 47 -87.672271
# 48 -87.716382
# 49 -87.668497
# 50 -87.650131
# 51 -87.723445
# 52 -87.706564
# 53 -87.717278
# 54 -87.718054
# 55 -87.628264
# 56 -87.623620
# 57 -87.566279
# 58 -87.727450
# 59 -87.708003
# 60 -87.640628
# 61 -87.657206
# 62 -87.608501
# 63 -87.691619
# 64 -87.688135
# 65 -87.746688
#
# [66 rows x 17 columns]
